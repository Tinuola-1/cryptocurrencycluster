# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import hvplot.pandas
import plotly.figure_factory as ff
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-102-edbb14aec1d5> in <module>
#       3 from sklearn.decomposition import PCA
#       4 from sklearn.cluster import KMeans
# ----> 5 import hvplot.pandas
#       6 import plotly.figure_factory as ff
#       7 import plotly.express as px
#
# ModuleNotFoundError: No module named 'hvplot'

# %%
file_path =r"C:\Users\tinuo\OneDrive\Desktop\crypto_data.csv"
crypto_df = pd.read_csv(file_path, index_col =0)
crypto_df.tail(5)
# Out:
#             CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# XBC      BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# DVTC      DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# GIOT     Giotto Coin    Scrypt      False   PoW/PoS              NaN
# OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# PUNK       SteamPunk       PoS      False       PoS              NaN
#
#      TotalCoinSupply
# XBC          1000000
# DVTC       100000000
# GIOT       233100000
# OPSC        21000000
# PUNK        40000000

# %%
#Discard all cryptocurrencies that are not being traded
crypto_df = crypto_df[crypto_df.IsTrading]
crypto_df.tail(5)
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# SERO   Super Zero       Ethash       True       PoW              NaN
# UOS           UOS      SHA-256       True      DPoI              NaN
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# SERO      1000000000
# UOS       1000000000
# BDX       1400222610
# ZEN         21000000
# XBC          1000000

# %%
# Remove all cryptocurrencies that don’t have a defined algorithm 
crypto_df = crypto_df.dropna(subset=["Algorithm"])
crypto_df.shape
# Out:
# (1144, 6)

# %%
# Remove the IsTrading column.
crypto_df.drop("IsTrading", axis=1, inplace=True)
crypto_df.shape
# Out:
# (1144, 5)

# %%
#Remove all rows that have at least one null value.
crypto_df = crypto_df.dropna()
crypto_df.shape
# Out:
# (685, 5)

# %%
#Filter for cryptocurrencies that have been mined
crypto_df.drop(crypto_df.loc[crypto_df['TotalCoinsMined'] <= 0].index, inplace=True)
crypto_df.shape
# Out:
# (532, 5)

# %%
# Store the names of all cryptocurrencies on a DataFramed named coins_name, then use the crypto_df.index as the index for this new DataFrame.
coins_name = pd.DataFrame(crypto_df, index=crypto_df.index, columns=['CoinName'])
coins_name
# Out:
#          CoinName
# 42        42 Coin
# 404       404Coin
# 1337    EliteCoin
# BTC       Bitcoin
# ETH      Ethereum
# ...           ...
# ZEPH       ZEPHYR
# GAP       Gapcoin
# BDX        Beldex
# ZEN       Horizen
# XBC   BitcoinPlus
#
# [532 rows x 1 columns]

# %%
#delete the `CoinName` from the original dataframe.
crypto_df = crypto_df.drop(['CoinName'], axis = 1)
crypto_df

#df=pd.read_csv("crypto_data.csv").drop(['CoinName'], axis = 1)
#df.head(5)
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01              42
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       SHA-256       PoW     1.792718e+07        21000000
# ETH        Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX   CryptoNight       PoW     9.802226e+08      1400222610
# ZEN      Equihash       PoW     7.296538e+06        21000000
# XBC        Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
X= pd.get_dummies(crypto_df)
X.head()
# Out:
#       TotalCoinsMined  Algorithm_1GB AES Pattern Search  Algorithm_536  \
# 42       4.199995e+01                                 0              0
# 404      1.055185e+09                                 0              0
# 1337     2.927942e+10                                 0              0
# BTC      1.792718e+07                                 0              0
# ETH      1.076842e+08                                 0              0
#
#       Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                    0                   0                0
# 404                   0                   0                0
# 1337                  0                   0                0
# BTC                   0                   0                0
# ETH                   0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  \
# 42                    0                  0              0
# ...

# %%
X_scaled = StandardScaler().fit_transform(X)
print(X_scaled[0:5])
# Out:
# [[-0.11710817 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.09396955 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [ 0.52494561 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.11671506 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.11474682 -0.0433963  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]]

# %%
#Perform dimensionality reduction with PCA
pca = PCA(n_components=3)

# %%
#Transform PCA datainto a dataframe
X_pca = pca.fit_transform(X_scaled)
pcs_df = pd.DataFrame(data=X_pca, columns=["PC 1", "PC 2", "PC 3"], index=crypto_df.index)
pcs_df.head()
# Out:
#           PC 1      PC 2      PC 3
# 42   -0.322587 -0.147378  0.112523
# 404  -0.301156 -0.151469  0.107724
# 1337  0.433476 -0.000659  0.225173
# BTC  -0.257766 -0.182799 -0.023684
# ETH  -0.124486 -0.207071 -0.019103

# %%
#EXplained variance
pca.explained_variance_ratio_
# Out:
# array([0.0083725 , 0.0079787 , 0.00795149])

# %%
#Best value for K
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of K values
for i in k:
	km = KMeans(n_clusters=i, random_state=0)
	km.fit(pcs_df)
	inertia.append(km.inertia_)

# Create the elbow curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# C:\Users\tinuo\Anaconda3\envs\PythonAdv\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   f"KMeans is known to have a memory leak on Windows "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-a9f091c4175f> in <module>
#      12 elbow_data = {"k": k, "inertia": inertia}
#      13 df_elbow = pd.DataFrame(elbow_data)
# ---> 14 df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
#
# ~\Anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# ...

# %%
#Predicting K clusters
model = KMeans(n_clusters=5, random_state=5)
model
model.fit(pcs_df)
predictions = model.predict(pcs_df)
pcs_df["class"] = model.labels_
pcs_df.head()
# Out:
#           PC 1      PC 2      PC 3  class
# 42   -0.322587 -0.147378  0.112523      0
# 404  -0.301156 -0.151469  0.107724      0
# 1337  0.433476 -0.000659  0.225173      0
# BTC  -0.257766 -0.182799 -0.023684      0
# ETH  -0.124486 -0.207071 -0.019103      0

# %%
#Can the cryptocurrencies be clustered together?
clustered_df = pd.merge(crypto_df, pcs_df, left_index=True, right_index = True)
clustered_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1      PC 2  \
# 42      Scrypt   PoW/PoS     4.199995e+01              42 -0.322587 -0.147378
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000 -0.301156 -0.151469
# 1337       X13   PoW/PoS     2.927942e+10    314159265359  0.433476 -0.000659
# BTC    SHA-256       PoW     1.792718e+07        21000000 -0.257766 -0.182799
# ETH     Ethash       PoW     1.076842e+08               0 -0.124486 -0.207071
#
#           PC 3  class
# 42    0.112523      0
# 404   0.107724      0
# 1337  0.225173      0
# BTC  -0.023684      0
# ETH  -0.019103      0

# %%
#add the coin name back
clustered_df = pd.merge(clustered_df, coins_name, left_index=True, right_index = True)
clustered_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1      PC 2  \
# 42      Scrypt   PoW/PoS     4.199995e+01              42 -0.322587 -0.147378
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000 -0.301156 -0.151469
# 1337       X13   PoW/PoS     2.927942e+10    314159265359  0.433476 -0.000659
# BTC    SHA-256       PoW     1.792718e+07        21000000 -0.257766 -0.182799
# ETH     Ethash       PoW     1.076842e+08               0 -0.124486 -0.207071
#
#           PC 3  class   CoinName
# 42    0.112523      0    42 Coin
# 404   0.107724      0    404Coin
# 1337  0.225173      0  EliteCoin
# BTC  -0.023684      0    Bitcoin
# ETH  -0.019103      0   Ethereum
